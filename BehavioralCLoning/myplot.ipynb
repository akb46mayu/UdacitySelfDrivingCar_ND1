# %%
# loss and validation loss from 3 epochs
loss = [0.02440677276006181, 0.02003397096643533, 0.019108049418377196, 0.019082042173457096, 0.018472521693989535]
validation_loss = [0.02117623881349573, 0.023879028104097304, 0.018542175719630904, 0.017321805250317568, 0.017576596947037615]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

### plot the training and validation loss vs epoch
plt.plot(loss)
plt.plot(validation_loss)
plt.title('model MSE loss')
plt.ylabel('MSE loss')
plt.xlabel('epoch')
plt.legend(['training set', 'validation set'], loc='upper right')
plt.grid(color='black', linestyle='--', linewidth=1)
plt.show()
